# %%
import os
import subprocess
from datetime import datetime

from sagemaker import get_execution_role
from sagemaker.tensorflow import TensorFlow
from sagemaker.inputs import FileSystemInput

# %%
# Set the default region
region = "us-east-1"
os.environ['AWS_DEFAULT_REGION'] = region
role = get_execution_role()

user_id = "muziy"
time_str = datetime.now().strftime("%H-%M-%S")

instance_type = "ml.p4d.24xlarge"
instance_count = 8

# smddp and horovod are supported
dist = 'smddp' # smddp and horovod are supported
if dist == 'smddp':
    distribution = {"smdistributed": {"dataparallel": {"enabled": True}}}
elif dist == 'horovod':
    custom_mpi_options = ['-x FI_EFA_USE_DEVICE_RDMA=1']
    distribution = {"mpi": {"enabled": True, "custom_mpi_options": " ".join(custom_mpi_options)}}

job_name = f'{user_id}-resnet101-p4d-{instance_count}-{dist}-{time_str}'

source_dir = "."
entry_point = "resnet_101_imagenet.py"

docker_image = "570106654206.dkr.ecr.us-east-1.amazonaws.com/muziy-keras:tf251-maskrcnn-indu-train-begin"

# %%
estimator = TensorFlow(
            entry_point=entry_point,
            role=role,
            image_uri=docker_image,
            source_dir=source_dir,
            instance_count=instance_count,
            instance_type=instance_type,
            subnets=['subnet-0fe4a69647f7b95f3'],
            security_group_ids=['sg-07306d8b4a69268b1'],
            disable_profiler=True,
            debugger_hook_config=False,
            distribution=distribution)

# %%
file_system_directory_path = '/fsx/dataset/imagenet/tfrecords'
file_system_access_mode = 'ro'
train_fs = FileSystemInput(
    file_system_id='fs-0a1be54e499ac3d67',
    file_system_type='FSxLustre',
    directory_path=file_system_directory_path,
    file_system_access_mode=file_system_access_mode)
data = {"train": train_fs}
estimator.fit(inputs=data, job_name=job_name)
# Out:
# 2021-10-19 20:39:22 Starting - Starting the training job...
# 2021-10-19 20:39:25 Starting - Launching requested ML instances.....................
# 2021-10-19 20:43:21 Starting - Preparing the instances for training....................................
# 2021-10-19 20:49:07 Downloading - Downloading input data
# 2021-10-19 20:49:07 Training - Downloading the training image.....................
# 2021-10-19 20:52:54 Training - Training image download completed. Training in progress.2021-10-19 20:52:47.502928: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# 2021-10-19 20:52:47.510074: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:105] SageMaker Profiler is not enabled. The timeline writer thread will not be started, future recorded events will be dropped.
# 2021-10-19 20:52:47.695733: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2021-10-19 20:52:47.845822: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# 2021-10-19 20:52:46.303628: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# 2021-10-19 20:52:46.310571: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:105] SageMaker Profiler is not enabled. The timeline writer thread will not be started, future recorded events will be dropped.
# 2021-10-19 20:52:46.477931: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2021-10-19 20:52:46.608715: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# 2021-10-19 20:52:49,352 sagemaker-training-toolkit INFO     Imported framework sagemaker_tensorflow_container.training
# 2021-10-19 20:52:47.467133: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# 2021-10-19 20:52:47.471248: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:105] SageMaker Profiler is not enabled. The timeline writer thread will not be started, future recorded events will be dropped.
# 2021-10-19 20:52:47.588956: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2021-10-19 20:52:47.703100: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# 2021-10-19 20:52:51,082 sagemaker-training-toolkit INFO     Imported framework sagemaker_tensorflow_container.training
# 2021-10-19 20:52:51,300 sagemaker-training-toolkit INFO     Imported framework sagemaker_tensorflow_container.training
# 2021-10-19 20:52:48.557034: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# 2021-10-19 20:52:48.564011: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:105] SageMaker Profiler is not enabled. The timeline writer thread will not be started, future recorded events will be dropped.
# 2021-10-19 20:52:48.753987: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2021-10-19 20:52:48.908012: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# 2021-10-19 20:52:51,974 sagemaker-training-toolkit INFO     Imported framework sagemaker_tensorflow_container.training
# 2021-10-19 20:52:51.875349: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# 2021-10-19 20:52:51.885591: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:105] SageMaker Profiler is not enabled. The timeline writer thread will not be started, future recorded events will be dropped.
# 2021-10-19 20:52:52.184140: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2021-10-19 20:52:52.405751: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# 2021-10-19 20:52:56,929 sagemaker-training-toolkit INFO     Imported framework sagemaker_tensorflow_container.training
# 2021-10-19 20:52:56,310 sagemaker-training-toolkit INFO     Starting MPI run as worker node.
# 2021-10-19 20:52:56,310 sagemaker-training-toolkit INFO     Waiting for MPI Master to create SSH daemon.
# 2021-10-19 20:52:56,312 sagemaker-training-toolkit INFO     Cannot connect to host algo-1
# 2021-10-19 20:52:56,312 sagemaker-training-toolkit INFO     Connection failed with exception:
#  [Errno None] Unable to connect to port 22 on 172.30.2.186
# 2021-10-19 20:52:52.294581: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# 2021-10-19 20:52:52.302351: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:105] SageMaker Profiler is not enabled. The timeline writer thread will not be started, future recorded events will be dropped.
# 2021-10-19 20:52:52.513577: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2021-10-19 20:52:52.680962: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# 2021-10-19 20:52:56,206 sagemaker-training-toolkit INFO     Imported framework sagemaker_tensorflow_container.training
# 2021-10-19 20:52:57,010 sagemaker-training-toolkit INFO     Starting MPI run as worker node.
# 2021-10-19 20:52:57,011 sagemaker-training-toolkit INFO     Waiting for MPI Master to create SSH daemon.
# 2021-10-19 20:52:57,012 sagemaker-training-toolkit INFO     Cannot connect to host algo-1
# 2021-10-19 20:52:57,012 sagemaker-training-toolkit INFO     Connection failed with exception:
#  [Errno None] Unable to connect to port 22 on 172.30.2.186
# 2021-10-19 20:52:57,920 sagemaker-training-toolkit INFO     Starting MPI run as worker node.
# 2021-10-19 20:52:57,920 sagemaker-training-toolkit INFO     Waiting for MPI Master to create SSH daemon.
# 2021-10-19 20:52:57,922 sagemaker-training-toolkit INFO     Cannot connect to host algo-1
# 2021-10-19 20:52:57,923 sagemaker-training-toolkit INFO     Connection failed with exception:
#  [Errno None] Unable to connect to port 22 on 172.30.2.186
# 2021-10-19 20:52:56.287168: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# 2021-10-19 20:52:56.294215: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:105] SageMaker Profiler is not enabled. The timeline writer thread will not be started, future recorded events will be dropped.
# 2021-10-19 20:52:56.543710: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2021-10-19 20:52:56.689659: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# 2021-10-19 20:52:57,315 sagemaker-training-toolkit INFO     Cannot connect to host algo-1
# 2021-10-19 20:52:57,315 sagemaker-training-toolkit INFO     Connection failed with exception:
#  [Errno None] Unable to connect to port 22 on 172.30.2.186
# 2021-10-19 20:52:58,015 sagemaker-training-toolkit INFO     Cannot connect to host algo-1
# 2021-10-19 20:52:58,016 sagemaker-training-toolkit INFO     Connection failed with exception:
#  [Errno None] Unable to connect to port 22 on 172.30.2.186
# 2021-10-19 20:52:58,154 sagemaker-training-toolkit INFO     Starting MPI run as worker node.
# 2021-10-19 20:52:58,155 sagemaker-training-toolkit INFO     Waiting for MPI Master to create SSH daemon.
# 2021-10-19 20:52:58,156 sagemaker-training-toolkit INFO     Cannot connect to host algo-1
# 2021-10-19 20:52:58,157 sagemaker-training-toolkit INFO     Connection failed with exception:
#  [Errno None] Unable to connect to port 22 on 172.30.2.186
# 2021-10-19 20:52:58,327 sagemaker-training-toolkit INFO     Starting MPI run as worker node.
# 2021-10-19 20:52:58,327 sagemaker-training-toolkit INFO     Waiting for MPI Master to create SSH daemon.
# 2021-10-19 20:52:58,330 sagemaker-training-toolkit INFO     Cannot connect to host algo-1
# 2021-10-19 20:52:58,330 sagemaker-training-toolkit INFO     Connection failed with exception:
#  [Errno None] Unable to connect to port 22 on 172.30.2.186
# 2021-10-19 20:52:58,925 sagemaker-training-toolkit INFO     Cannot connect to host algo-1
# 2021-10-19 20:52:58,925 sagemaker-training-toolkit INFO     Connection failed with exception:
#  [Errno None] Unable to connect to port 22 on 172.30.2.186
# 2021-10-19 20:52:58,317 sagemaker-training-toolkit INFO     Cannot connect to host algo-1
# 2021-10-19 20:52:58,318 sagemaker-training-toolkit INFO     Connection failed with exception:
#  [Errno None] Unable to connect to port 22 on 172.30.2.186
# 2021-10-19 20:52:59,018 sagemaker-training-toolkit INFO     Cannot connect to host algo-1
# 2021-10-19 20:52:59,019 sagemaker-training-toolkit INFO     Connection failed with exception:
#  [Errno None] Unable to connect to port 22 on 172.30.2.186
# 2021-10-19 20:52:58,969 sagemaker-training-toolkit INFO     Starting MPI run as worker node.
# 2021-10-19 20:52:58,969 sagemaker-training-toolkit INFO     Waiting for MPI Master to create SSH daemon.
# 2021-10-19 20:52:58,971 sagemaker-training-toolkit INFO     Cannot connect to host algo-1
# 2021-10-19 20:52:58,972 sagemaker-training-toolkit INFO     Connection failed with exception:
#  [Errno None] Unable to connect to port 22 on 172.30.2.186
# 2021-10-19 20:52:59,160 sagemaker-training-toolkit INFO     Cannot connect to host algo-1
# 2021-10-19 20:52:59,160 sagemaker-training-toolkit INFO     Connection failed with exception:
#  [Errno None] Unable to connect to port 22 on 172.30.2.186
# 2021-10-19 20:52:59,332 sagemaker-training-toolkit INFO     Cannot connect to host algo-1
# 2021-10-19 20:52:59,333 sagemaker-training-toolkit INFO     Connection failed with exception:
#  [Errno None] Unable to connect to port 22 on 172.30.2.186
# 2021-10-19 20:52:59,928 sagemaker-training-toolkit INFO     Cannot connect to host algo-1
# 2021-10-19 20:52:59,928 sagemaker-training-toolkit INFO     Connection failed with exception:
#  [Errno None] Unable to connect to port 22 on 172.30.2.186
# 2021-10-19 20:52:59,320 sagemaker-training-toolkit INFO     Cannot connect to host algo-1
# 2021-10-19 20:52:59,320 sagemaker-training-toolkit INFO     Connection failed with exception:
#  [Errno None] Unable to connect to port 22 on 172.30.2.186
# 2021-10-19 20:53:00,021 sagemaker-training-toolkit INFO     Cannot connect to host algo-1
# 2021-10-19 20:53:00,021 sagemaker-training-toolkit INFO     Connection failed with exception:
#  [Errno None] Unable to connect to port 22 on 172.30.2.186
# 2021-10-19 20:52:59,974 sagemaker-training-toolkit INFO     Cannot connect to host algo-1
# 2021-10-19 20:52:59,974 sagemaker-training-toolkit INFO     Connection failed with exception:
#  [Errno None] Unable to connect to port 22 on 172.30.2.186
# 2021-10-19 20:53:00,162 sagemaker-training-toolkit INFO     Cannot connect to host algo-1
# 2021-10-19 20:53:00,163 sagemaker-training-toolkit INFO     Connection failed with exception:
#  [Errno None] Unable to connect to port 22 on 172.30.2.186
# 2021-10-19 20:53:00,334 sagemaker-training-toolkit INFO     Cannot connect to host algo-1
# 2021-10-19 20:53:00,334 sagemaker-training-toolkit INFO     Connection failed with exception:
#  [Errno None] Unable to connect to port 22 on 172.30.2.186
# 2021-10-19 20:53:00,930 sagemaker-training-toolkit INFO     Cannot connect to host algo-1
# 2021-10-19 20:53:00,931 sagemaker-training-toolkit INFO     Connection failed with exception:
#  [Errno None] Unable to connect to port 22 on 172.30.2.186
# 2021-10-19 20:53:00,323 sagemaker-training-toolkit INFO     Cannot connect to host algo-1
# 2021-10-19 20:53:00,323 sagemaker-training-toolkit INFO     Connection failed with exception:
#  [Errno None] Unable to connect to port 22 on 172.30.2.186
# 2021-10-19 20:53:01,023 sagemaker-training-toolkit INFO     Cannot connect to host algo-1
# 2021-10-19 20:53:01,023 sagemaker-training-toolkit INFO     Connection failed with exception:
#  [Errno None] Unable to connect to port 22 on 172.30.2.186
# 2021-10-19 20:53:00,977 sagemaker-training-toolkit INFO     Cannot connect to host algo-1
# 2021-10-19 20:53:00,977 sagemaker-training-toolkit INFO     Connection failed with exception:
#  [Errno None] Unable to connect to port 22 on 172.30.2.186
# 2021-10-19 20:52:56.713046: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# 2021-10-19 20:52:56.725469: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:105] SageMaker Profiler is not enabled. The timeline writer thread will not be started, future recorded events will be dropped.
# 2021-10-19 20:52:57.077365: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2021-10-19 20:52:57.351869: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# 2021-10-19 20:53:01,165 sagemaker-training-toolkit INFO     Cannot connect to host algo-1
# 2021-10-19 20:53:01,165 sagemaker-training-toolkit INFO     Connection failed with exception:
#  [Errno None] Unable to connect to port 22 on 172.30.2.186
# 2021-10-19 20:53:01,337 sagemaker-training-toolkit INFO     Cannot connect to host algo-1
# 2021-10-19 20:53:01,337 sagemaker-training-toolkit INFO     Connection failed with exception:
#  [Errno None] Unable to connect to port 22 on 172.30.2.186
# 2021-10-19 20:53:01,933 sagemaker-training-toolkit INFO     Cannot connect to host algo-1
# 2021-10-19 20:53:01,933 sagemaker-training-toolkit INFO     Connection failed with exception:
#  [Errno None] Unable to connect to port 22 on 172.30.2.186
# 2021-10-19 20:53:01,325 sagemaker-training-toolkit INFO     Cannot connect to host algo-1
# 2021-10-19 20:53:01,325 sagemaker-training-toolkit INFO     Connection failed with exception:
#  [Errno None] Unable to connect to port 22 on 172.30.2.186
# 2021-10-19 20:53:02,025 sagemaker-training-toolkit INFO     Cannot connect to host algo-1
# 2021-10-19 20:53:02,025 sagemaker-training-toolkit INFO     Connection failed with exception:
#  [Errno None] Unable to connect to port 22 on 172.30.2.186
# 2021-10-19 20:53:01,979 sagemaker-training-toolkit INFO     Cannot connect to host algo-1
# 2021-10-19 20:53:01,979 sagemaker-training-toolkit INFO     Connection failed with exception:
#  [Errno None] Unable to connect to port 22 on 172.30.2.186
# 2021-10-19 20:53:02,168 sagemaker-training-toolkit INFO     Cannot connect to host algo-1
# 2021-10-19 20:53:02,168 sagemaker-training-toolkit INFO     Connection failed with exception:
#  [Errno None] Unable to connect to port 22 on 172.30.2.186
# 2021-10-19 20:53:02,339 sagemaker-training-toolkit INFO     Cannot connect to host algo-1
# 2021-10-19 20:53:02,339 sagemaker-training-toolkit INFO     Connection failed with exception:
#  [Errno None] Unable to connect to port 22 on 172.30.2.186
# 2021-10-19 20:53:02,935 sagemaker-training-toolkit INFO     Cannot connect to host algo-1
# 2021-10-19 20:53:02,935 sagemaker-training-toolkit INFO     Connection failed with exception:
#  [Errno None] Unable to connect to port 22 on 172.30.2.186
# 2021-10-19 20:53:02,348 sagemaker-training-toolkit INFO     Imported framework sagemaker_tensorflow_container.training
# 2021-10-19 20:53:02,327 sagemaker-training-toolkit INFO     Cannot connect to host algo-1
# 2021-10-19 20:53:02,327 sagemaker-training-toolkit INFO     Connection failed with exception:
#  [Errno None] Unable to connect to port 22 on 172.30.2.186
# 2021-10-19 20:53:03,027 sagemaker-training-toolkit INFO     Cannot connect to host algo-1
# 2021-10-19 20:53:03,027 sagemaker-training-toolkit INFO     Connection failed with exception:
#  [Errno None] Unable to connect to port 22 on 172.30.2.186
# 2021-10-19 20:53:02,981 sagemaker-training-toolkit INFO     Cannot connect to host algo-1
# 2021-10-19 20:53:02,981 sagemaker-training-toolkit INFO     Connection failed with exception:
#  [Errno None] Unable to connect to port 22 on 172.30.2.186
# 2021-10-19 20:53:03,600 sagemaker-training-toolkit INFO     Imported framework sagemaker_tensorflow_container.training
# 2021-10-19 20:53:03,170 sagemaker-training-toolkit INFO     Cannot connect to host algo-1
# 2021-10-19 20:53:03,170 sagemaker-training-toolkit INFO     Connection failed with exception:
#  [Errno None] Unable to connect to port 22 on 172.30.2.186
# 2021-10-19 20:53:03,341 sagemaker-training-toolkit INFO     Cannot connect to host algo-1
# 2021-10-19 20:53:03,341 sagemaker-training-toolkit INFO     Connection failed with exception:
#  [Errno None] Unable to connect to port 22 on 172.30.2.186
# 2021-10-19 20:53:03,938 sagemaker-training-toolkit INFO     Cannot connect to host algo-1
# 2021-10-19 20:53:03,938 sagemaker-training-toolkit INFO     Connection failed with exception:
#  [Errno None] Unable to connect to port 22 on 172.30.2.186
# 2021-10-19 20:53:03,455 sagemaker-training-toolkit INFO     Starting MPI run as worker node.
# 2021-10-19 20:53:03,455 sagemaker-training-toolkit INFO     Waiting for MPI Master to create SSH daemon.
# 2021-10-19 20:53:03,457 sagemaker-training-toolkit INFO     Cannot connect to host algo-1
# 2021-10-19 20:53:03,457 sagemaker-training-toolkit INFO     Connection failed with exception:
#  [Errno None] Unable to connect to port 22 on 172.30.2.186
# 2021-10-19 20:53:03,329 sagemaker-training-toolkit INFO     Cannot connect to host algo-1
# 2021-10-19 20:53:03,329 sagemaker-training-toolkit INFO     Connection failed with exception:
#  [Errno None] Unable to connect to port 22 on 172.30.2.186
# 2021-10-19 20:53:04,029 sagemaker-training-toolkit INFO     Cannot connect to host algo-1
# 2021-10-19 20:53:04,029 sagemaker-training-toolkit INFO     Connection failed with exception:
#  [Errno None] Unable to connect to port 22 on 172.30.2.186
# 2021-10-19 20:53:03,984 sagemaker-training-toolkit INFO     Cannot connect to host algo-1
# 2021-10-19 20:53:03,984 sagemaker-training-toolkit INFO     Connection failed with exception:
#  [Errno None] Unable to connect to port 22 on 172.30.2.186
# 2021-10-19 20:53:04,172 sagemaker-training-toolkit INFO     Cannot connect to host algo-1
# 2021-10-19 20:53:04,173 sagemaker-training-toolkit INFO     Connection failed with exception:
#  [Errno None] Unable to connect to port 22 on 172.30.2.186
# 2021-10-19 20:53:04,343 sagemaker-training-toolkit INFO     Cannot connect to host algo-1
# 2021-10-19 20:53:04,343 sagemaker-training-toolkit INFO     Connection failed with exception:
#  [Errno None] Unable to connect to port 22 on 172.30.2.186
# 2021-10-19 20:53:04,939 sagemaker-training-toolkit INFO     Cannot connect to host algo-1
# 2021-10-19 20:53:04,940 sagemaker-training-toolkit INFO     Connection failed with exception:
#  [Errno None] Unable to connect to port 22 on 172.30.2.186
# 2021-10-19 20:53:04,459 sagemaker-training-toolkit INFO     Cannot connect to host algo-1
# 2021-10-19 20:53:04,459 sagemaker-training-toolkit INFO     Connection failed with exception:
#  [Errno None] Unable to connect to port 22 on 172.30.2.186
# 2021-10-19 20:53:04,332 sagemaker-training-toolkit INFO     Cannot connect to host algo-1
# 2021-10-19 20:53:04,332 sagemaker-training-toolkit INFO     Connection failed with exception:
#  [Errno None] Unable to connect to port 22 on 172.30.2.186
# 2021-10-19 20:53:05,031 sagemaker-training-toolkit INFO     Cannot connect to host algo-1
# 2021-10-19 20:53:05,031 sagemaker-training-toolkit INFO     Connection failed with exception:
#  [Errno None] Unable to connect to port 22 on 172.30.2.186
# 2021-10-19 20:53:04,985 sagemaker-training-toolkit INFO     Cannot connect to host algo-1
# 2021-10-19 20:53:04,986 sagemaker-training-toolkit INFO     Connection failed with exception:
#  [Errno None] Unable to connect to port 22 on 172.30.2.186
# 2021-10-19 20:53:05,006 sagemaker-training-toolkit INFO     Starting MPI run as worker node.
# 2021-10-19 20:53:05,006 sagemaker-training-toolkit INFO     Creating SSH daemon.
# 2021-10-19 20:53:05,019 sagemaker-training-toolkit INFO     Waiting for MPI workers to establish their SSH connections
# 2021-10-19 20:53:05,021 sagemaker-training-toolkit INFO     Cannot connect to host algo-2 at port 22. Retrying...
# 2021-10-19 20:53:05,021 sagemaker-training-toolkit INFO     Connection closed
# 2021-10-19 20:53:05,181 paramiko.transport INFO     Connected (version 2.0, client OpenSSH_7.6p1)
# 2021-10-19 20:53:05,262 paramiko.transport INFO     Authentication (publickey) successful!
# 2021-10-19 20:53:05,262 sagemaker-training-toolkit INFO     Can connect to host algo-1
# 2021-10-19 20:53:05,263 sagemaker-training-toolkit INFO     MPI Master online, creating SSH daemon.
# 2021-10-19 20:53:05,263 sagemaker-training-toolkit INFO     Writing environment variables to /etc/environment for the MPI process.
# 2021-10-19 20:53:05,271 sagemaker-training-toolkit INFO     Waiting for MPI process to finish.
# 2021-10-19 20:53:05,350 paramiko.transport INFO     Connected (version 2.0, client OpenSSH_7.6p1)
# 2021-10-19 20:53:05,405 paramiko.transport INFO     Authentication (publickey) successful!
# 2021-10-19 20:53:05,406 sagemaker-training-toolkit INFO     Can connect to host algo-1
# 2021-10-19 20:53:05,406 sagemaker-training-toolkit INFO     MPI Master online, creating SSH daemon.
# 2021-10-19 20:53:05,406 sagemaker-training-toolkit INFO     Writing environment variables to /etc/environment for the MPI process.
# 2021-10-19 20:53:05,415 sagemaker-training-toolkit INFO     Waiting for MPI process to finish.
# 2021-10-19 20:53:05,947 paramiko.transport INFO     Connected (version 2.0, client OpenSSH_7.6p1)
# 2021-10-19 20:53:05,466 paramiko.transport INFO     Connected (version 2.0, client OpenSSH_7.6p1)
# 2021-10-19 20:53:05,522 paramiko.transport INFO     Authentication (publickey) successful!
# 2021-10-19 20:53:05,522 sagemaker-training-toolkit INFO     Can connect to host algo-1
# 2021-10-19 20:53:05,522 sagemaker-training-toolkit INFO     MPI Master online, creating SSH daemon.
# 2021-10-19 20:53:05,522 sagemaker-training-toolkit INFO     Writing environment variables to /etc/environment for the MPI process.
# 2021-10-19 20:53:05,532 sagemaker-training-toolkit INFO     Waiting for MPI process to finish.
# 2021-10-19 20:53:05,338 paramiko.transport INFO     Connected (version 2.0, client OpenSSH_7.6p1)
# 2021-10-19 20:53:05,393 paramiko.transport INFO     Authentication (publickey) successful!
# 2021-10-19 20:53:05,394 sagemaker-training-toolkit INFO     Can connect to host algo-1
# 2021-10-19 20:53:05,394 sagemaker-training-toolkit INFO     MPI Master online, creating SSH daemon.
# 2021-10-19 20:53:05,394 sagemaker-training-toolkit INFO     Writing environment variables to /etc/environment for the MPI process.
# 2021-10-19 20:53:05,402 sagemaker-training-toolkit INFO     Waiting for MPI process to finish.
# 2021-10-19 20:53:06,037 paramiko.transport INFO     Connected (version 2.0, client OpenSSH_7.6p1)
# 2021-10-19 20:53:05,992 paramiko.transport INFO     Connected (version 2.0, client OpenSSH_7.6p1)
# 2021-10-19 20:53:06,047 paramiko.transport INFO     Authentication (publickey) successful!
# 2021-10-19 20:53:06,048 sagemaker-training-toolkit INFO     Can connect to host algo-1
# 2021-10-19 20:53:06,048 sagemaker-training-toolkit INFO     MPI Master online, creating SSH daemon.
# 2021-10-19 20:53:06,048 sagemaker-training-toolkit INFO     Writing environment variables to /etc/environment for the MPI process.
# 2021-10-19 20:53:06,058 sagemaker-training-toolkit INFO     Waiting for MPI process to finish.
# 2021-10-19 20:53:06,003 paramiko.transport INFO     Authentication (publickey) successful!
# 2021-10-19 20:53:06,003 sagemaker-training-toolkit INFO     Can connect to host algo-1
# 2021-10-19 20:53:06,003 sagemaker-training-toolkit INFO     MPI Master online, creating SSH daemon.
# 2021-10-19 20:53:06,003 sagemaker-training-toolkit INFO     Writing environment variables to /etc/environment for the MPI process.
# 2021-10-19 20:53:06,013 sagemaker-training-toolkit INFO     Waiting for MPI process to finish.
# 2021-10-19 20:53:06,024 sagemaker-training-toolkit INFO     Cannot connect to host algo-2 at port 22. Retrying...
# 2021-10-19 20:53:06,024 sagemaker-training-toolkit INFO     Connection closed
# 2021-10-19 20:53:06,097 paramiko.transport INFO     Authentication (publickey) successful!
# 2021-10-19 20:53:06,097 sagemaker-training-toolkit INFO     Can connect to host algo-1
# 2021-10-19 20:53:06,098 sagemaker-training-toolkit INFO     MPI Master online, creating SSH daemon.
# 2021-10-19 20:53:06,098 sagemaker-training-toolkit INFO     Writing environment variables to /etc/environment for the MPI process.
# 2021-10-19 20:53:06,107 sagemaker-training-toolkit INFO     Waiting for MPI process to finish.
# 2021-10-19 20:53:07,031 paramiko.transport INFO     Connected (version 2.0, client OpenSSH_7.6p1)
# 2021-10-19 20:53:07,107 paramiko.transport INFO     Authentication (publickey) successful!
# 2021-10-19 20:53:07,107 sagemaker-training-toolkit INFO     Can connect to host algo-2 at port 22
# 2021-10-19 20:53:07,108 sagemaker-training-toolkit INFO     Connection closed
# 2021-10-19 20:53:07,108 sagemaker-training-toolkit INFO     Worker algo-2 available for communication
# 2021-10-19 20:53:07,119 paramiko.transport INFO     Connected (version 2.0, client OpenSSH_7.6p1)
# 2021-10-19 20:53:07,204 paramiko.transport INFO     Authentication (publickey) successful!
# 2021-10-19 20:53:07,204 sagemaker-training-toolkit INFO     Can connect to host algo-3 at port 22
# 2021-10-19 20:53:07,204 sagemaker-training-toolkit INFO     Connection closed
# 2021-10-19 20:53:07,204 sagemaker-training-toolkit INFO     Worker algo-3 available for communication
# 2021-10-19 20:53:07,210 paramiko.transport INFO     Connected (version 2.0, client OpenSSH_7.6p1)
# 2021-10-19 20:53:07,278 paramiko.transport INFO     Authentication (publickey) successful!
# 2021-10-19 20:53:07,278 sagemaker-training-toolkit INFO     Can connect to host algo-4 at port 22
# 2021-10-19 20:53:07,278 sagemaker-training-toolkit INFO     Connection closed
# 2021-10-19 20:53:07,278 sagemaker-training-toolkit INFO     Worker algo-4 available for communication
# 2021-10-19 20:53:07,284 paramiko.transport INFO     Connected (version 2.0, client OpenSSH_7.6p1)
# 2021-10-19 20:53:07,348 paramiko.transport INFO     Authentication (publickey) successful!
# 2021-10-19 20:53:07,348 sagemaker-training-toolkit INFO     Can connect to host algo-5 at port 22
# 2021-10-19 20:53:07,348 sagemaker-training-toolkit INFO     Connection closed
# 2021-10-19 20:53:07,348 sagemaker-training-toolkit INFO     Worker algo-5 available for communication
# 2021-10-19 20:53:07,356 paramiko.transport INFO     Connected (version 2.0, client OpenSSH_7.6p1)
# 2021-10-19 20:53:07,420 paramiko.transport INFO     Authentication (publickey) successful!
# 2021-10-19 20:53:07,421 sagemaker-training-toolkit INFO     Can connect to host algo-6 at port 22
# 2021-10-19 20:53:07,421 sagemaker-training-toolkit INFO     Connection closed
# 2021-10-19 20:53:07,421 sagemaker-training-toolkit INFO     Worker algo-6 available for communication
# 2021-10-19 20:53:07,428 paramiko.transport INFO     Connected (version 2.0, client OpenSSH_7.6p1)
# 2021-10-19 20:53:07,505 paramiko.transport INFO     Authentication (publickey) successful!
# 2021-10-19 20:53:07,505 sagemaker-training-toolkit INFO     Can connect to host algo-7 at port 22
# 2021-10-19 20:53:07,505 sagemaker-training-toolkit INFO     Connection closed
# 2021-10-19 20:53:07,505 sagemaker-training-toolkit INFO     Worker algo-7 available for communication
# 2021-10-19 20:53:07,512 paramiko.transport INFO     Connected (version 2.0, client OpenSSH_7.6p1)
# 2021-10-19 20:53:07,580 paramiko.transport INFO     Authentication (publickey) successful!
# 2021-10-19 20:53:07,580 sagemaker-training-toolkit INFO     Can connect to host algo-8 at port 22
# 2021-10-19 20:53:07,580 sagemaker-training-toolkit INFO     Connection closed
# 2021-10-19 20:53:07,580 sagemaker-training-toolkit INFO     Worker algo-8 available for communication
# 2021-10-19 20:53:07,580 sagemaker-training-toolkit INFO     Network interface name: eth0
# 2021-10-19 20:53:07,580 sagemaker-training-toolkit INFO     Host: ['algo-1', 'algo-2', 'algo-3', 'algo-4', 'algo-5', 'algo-6', 'algo-7', 'algo-8']
# 2021-10-19 20:53:07,581 sagemaker-training-toolkit INFO     instance type: ml.p4d.24xlarge
# 2021-10-19 20:53:07,671 sagemaker-training-toolkit INFO     Invoking user script
#
# Training Env:
#
# {
#     "additional_framework_parameters": {
#         "sagemaker_distributed_dataparallel_enabled": true,
#         "sagemaker_distributed_dataparallel_custom_mpi_options": "",
#         "sagemaker_instance_type": "ml.p4d.24xlarge"
#     },
#     "channel_input_dirs": {
#         "train": "/opt/ml/input/data/train"
#     },
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_tensorflow_container.training:main",
#     "hosts": [
#         "algo-1",
#         "algo-2",
#         "algo-3",
#         "algo-4",
#         "algo-5",
#         "algo-6",
#         "algo-7",
#         "algo-8"
#     ],
#     "hyperparameters": {
#         "model_dir": "s3://sagemaker-us-east-1-570106654206/muziy-resnet101-p4d-8-smddp-20-39-20/model"
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "train": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "muziy-resnet101-p4d-8-smddp-20-39-20",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-us-east-1-570106654206/muziy-resnet101-p4d-8-smddp-20-39-20/source/sourcedir.tar.gz",
#     "module_name": "resnet_101_imagenet",
#     "network_interface_name": "eth0",
#     "num_cpus": 96,
#     "num_gpus": 8,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "hosts": [
#             "algo-1",
#             "algo-2",
#             "algo-3",
#             "algo-4",
#             "algo-5",
#             "algo-6",
#             "algo-7",
#             "algo-8"
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "resnet_101_imagenet.py"
# }
#
# Environment variables:
#
# SM_HOSTS=["algo-1","algo-2","algo-3","algo-4","algo-5","algo-6","algo-7","algo-8"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"model_dir":"s3://sagemaker-us-east-1-570106654206/muziy-resnet101-p4d-8-smddp-20-39-20/model"}
# SM_USER_ENTRY_POINT=resnet_101_imagenet.py
# SM_FRAMEWORK_PARAMS={"sagemaker_distributed_dataparallel_custom_mpi_options":"","sagemaker_distributed_dataparallel_enabled":true,"sagemaker_instance_type":"ml.p4d.24xlarge"}
# SM_RESOURCE_CONFIG={"current_host":"algo-1","hosts":["algo-1","algo-2","algo-3","algo-4","algo-5","algo-6","algo-7","algo-8"],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["train"]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=resnet_101_imagenet
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_tensorflow_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=96
# SM_NUM_GPUS=8
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-us-east-1-570106654206/muziy-resnet101-p4d-8-smddp-20-39-20/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{"sagemaker_distributed_dataparallel_custom_mpi_options":"","sagemaker_distributed_dataparallel_enabled":true,"sagemaker_instance_type":"ml.p4d.24xlarge"},"channel_input_dirs":{"train":"/opt/ml/input/data/train"},"current_host":"algo-1","framework_module":"sagemaker_tensorflow_container.training:main","hosts":["algo-1","algo-2","algo-3","algo-4","algo-5","algo-6","algo-7","algo-8"],"hyperparameters":{"model_dir":"s3://sagemaker-us-east-1-570106654206/muziy-resnet101-p4d-8-smddp-20-39-20/model"},"input_config_dir":"/opt/ml/input/config","input_data_config":{"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"muziy-resnet101-p4d-8-smddp-20-39-20","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-east-1-570106654206/muziy-resnet101-p4d-8-smddp-20-39-20/source/sourcedir.tar.gz","module_name":"resnet_101_imagenet","network_interface_name":"eth0","num_cpus":96,"num_gpus":8,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1","hosts":["algo-1","algo-2","algo-3","algo-4","algo-5","algo-6","algo-7","algo-8"],"network_interface_name":"eth0"},"user_entry_point":"resnet_101_imagenet.py"}
# SM_USER_ARGS=["--model_dir","s3://sagemaker-us-east-1-570106654206/muziy-resnet101-p4d-8-smddp-20-39-20/model"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_TRAIN=/opt/ml/input/data/train
# SM_HP_MODEL_DIR=s3://sagemaker-us-east-1-570106654206/muziy-resnet101-p4d-8-smddp-20-39-20/model
# PYTHONPATH=/opt/ml/code:/usr/local/bin:/usr/local/lib/python37.zip:/usr/local/lib/python3.7:/usr/local/lib/python3.7/lib-dynload:/usr/local/lib/python3.7/site-packages
#
# Invoking script with the following command:
#
# mpirun --host algo-1:8,algo-2:8,algo-3:8,algo-4:8,algo-5:8,algo-6:8,algo-7:8,algo-8:8 -np 64 --allow-run-as-root --tag-output --oversubscribe -mca btl_tcp_if_include eth0 -mca oob_tcp_if_include eth0 -mca plm_rsh_no_tree_spawn 1 -mca pml ob1 -mca btl ^openib -mca orte_abort_on_non_zero_status 1 -mca btl_vader_single_copy_mechanism none -mca plm_rsh_num_concurrent 8 -x NCCL_SOCKET_IFNAME=eth0 -x NCCL_DEBUG=INFO -x LD_LIBRARY_PATH -x PATH -x SMDATAPARALLEL_USE_HOMOGENEOUS=1 -x FI_PROVIDER=efa -x RDMAV_FORK_SAFE=1 -x LD_PRELOAD=/usr/local/lib/python3.7/site-packages/gethostname.cpython-37m-x86_64-linux-gnu.so -x SMDATAPARALLEL_SERVER_ADDR=algo-1 -x SMDATAPARALLEL_SERVER_PORT=7592 -x SAGEMAKER_INSTANCE_TYPE=ml.p4d.24xlarge smddprun /usr/local/bin/python3.7 -m mpi4py resnet_101_imagenet.py --model_dir s3://sagemaker-us-east-1-570106654206/muziy-resnet101-p4d-8-smddp-20-39-20/model
#
#
# 2021-10-19 20:53:09,069 sagemaker-training-toolkit INFO     Process[es]: [psutil.Process(pid=172, name='orted', status='sleeping', started='20:53:08')]
# 2021-10-19 20:53:09,069 sagemaker-training-toolkit INFO     Orted process found [psutil.Process(pid=172, name='orted', status='sleeping', started='20:53:08')]
# 2021-10-19 20:53:09,069 sagemaker-training-toolkit INFO     Waiting for orted process [psutil.Process(pid=172, name='orted', status='sleeping', started='20:53:08')]
# 2021-10-19 20:53:09,280 sagemaker-training-toolkit INFO     Process[es]: [psutil.Process(pid=172, name='orted', status='sleeping', started='20:53:07')]
# 2021-10-19 20:53:09,281 sagemaker-training-toolkit INFO     Orted process found [psutil.Process(pid=172, name='orted', status='sleeping', started='20:53:07')]
# 2021-10-19 20:53:09,281 sagemaker-training-toolkit INFO     Waiting for orted process [psutil.Process(pid=172, name='orted', status='sleeping', started='20:53:07')]
# 2021-10-19 20:53:09,425 sagemaker-training-toolkit INFO     Process[es]: [psutil.Process(pid=172, name='orted', status='sleeping', started='20:53:07')]
# 2021-10-19 20:53:09,425 sagemaker-training-toolkit INFO     Orted process found [psutil.Process(pid=172, name='orted', status='sleeping', started='20:53:07')]
# 2021-10-19 20:53:09,425 sagemaker-training-toolkit INFO     Waiting for orted process [psutil.Process(pid=172, name='orted', status='sleeping', started='20:53:07')]
# 2021-10-19 20:53:09,022 sagemaker-training-toolkit INFO     Process[es]: [psutil.Process(pid=172, name='orted', status='sleeping', started='20:53:07')]
# 2021-10-19 20:53:09,023 sagemaker-training-toolkit INFO     Orted process found [psutil.Process(pid=172, name='orted', status='sleeping', started='20:53:07')]
# 2021-10-19 20:53:09,023 sagemaker-training-toolkit INFO     Waiting for orted process [psutil.Process(pid=172, name='orted', status='sleeping', started='20:53:07')]
# 2021-10-19 20:53:09,541 sagemaker-training-toolkit INFO     Process[es]: [psutil.Process(pid=172, name='orted', status='sleeping', started='20:53:08')]
# 2021-10-19 20:53:09,541 sagemaker-training-toolkit INFO     Orted process found [psutil.Process(pid=172, name='orted', status='sleeping', started='20:53:08')]
# 2021-10-19 20:53:09,542 sagemaker-training-toolkit INFO     Waiting for orted process [psutil.Process(pid=172, name='orted', status='sleeping', started='20:53:08')]
# 2021-10-19 20:53:09,412 sagemaker-training-toolkit INFO     Process[es]: [psutil.Process(pid=172, name='orted', status='sleeping', started='20:53:08')]
# 2021-10-19 20:53:09,412 sagemaker-training-toolkit INFO     Orted process found [psutil.Process(pid=172, name='orted', status='sleeping', started='20:53:08')]
# 2021-10-19 20:53:09,412 sagemaker-training-toolkit INFO     Waiting for orted process [psutil.Process(pid=172, name='orted', status='sleeping', started='20:53:08')]
# 2021-10-19 20:53:09,117 sagemaker-training-toolkit INFO     Process[es]: [psutil.Process(pid=172, name='orted', status='sleeping', started='20:53:07')]
# 2021-10-19 20:53:09,117 sagemaker-training-toolkit INFO     Orted process found [psutil.Process(pid=172, name='orted', status='sleeping', started='20:53:07')]
# 2021-10-19 20:53:09,117 sagemaker-training-toolkit INFO     Waiting for orted process [psutil.Process(pid=172, name='orted', status='sleeping', started='20:53:07')]
# [1,40]<stdout>:algo-6:378:378 [0] NCCL INFO Bootstrap : Using eth0:172.30.2.229<0>
# [1,40]<stdout>:algo-6:378:378 [0] NCCL INFO NET/OFI Running on P4d platform, Setting NCCL_TOPO_FILE environment variable to /usr/local/share/aws-ofi-nccl/xml/p4d-24xl-topo.xml
# [1,8]<stdout>:algo-2:378:378 [0] NCCL INFO Bootstrap : Using eth0:172.30.2.8<0>
# [1,8]<stdout>:algo-2:378:378 [0] NCCL INFO NET/OFI Running on P4d platform, Setting NCCL_TOPO_FILE environment variable to /usr/local/share/aws-ofi-nccl/xml/p4d-24xl-topo.xml
# [1,56]<stdout>:algo-8:378:378 [0] NCCL INFO Bootstrap : Using eth0:172.30.2.181<0>
# [1,24]<stdout>:algo-4:378:378 [0] NCCL INFO Bootstrap : Using eth0:172.30.2.207<0>
# [1,56]<stdout>:algo-8:378:378 [0] NCCL INFO NET/OFI Running on P4d platform, Setting NCCL_TOPO_FILE environment variable to /usr/local/share/aws-ofi-nccl/xml/p4d-24xl-topo.xml
# [1,24]<stdout>:algo-4:378:378 [0] NCCL INFO NET/OFI Running on P4d platform, Setting NCCL_TOPO_FILE environment variable to /usr/local/share/aws-ofi-nccl/xml/p4d-24xl-topo.xml
# [1,16]<stdout>:algo-3:378:378 [0] NCCL INFO Bootstrap : Using eth0:172.30.2.17<0>
# [1,48]<stdout>:algo-7:378:378 [0] NCCL INFO Bootstrap : Using eth0:172.30.2.54<0>
# [1,16]<stdout>:algo-3:378:378 [0] NCCL INFO NET/OFI Running on P4d platform, Setting NCCL_TOPO_FILE environment variable to /usr/local/share/aws-ofi-nccl/xml/p4d-24xl-topo.xml
# [1,32]<stdout>:algo-5:378:378 [0] NCCL INFO Bootstrap : Using eth0:172.30.2.44<0>
# [1,48]<stdout>:algo-7:378:378 [0] NCCL INFO NET/OFI Running on P4d platform, Setting NCCL_TOPO_FILE environment variable to /usr/local/share/aws-ofi-nccl/xml/p4d-24xl-topo.xml
# [1,0]<stdout>:algo-1:453:453 [0] NCCL INFO Bootstrap : Using eth0:172.30.2.186<0>
# [1,32]<stdout>:algo-5:378:378 [0] NCCL INFO NET/OFI Running on P4d platform, Setting NCCL_TOPO_FILE environment variable to /usr/local/share/aws-ofi-nccl/xml/p4d-24xl-topo.xml
# [1,0]<stdout>:algo-1:453:453 [0] NCCL INFO NET/OFI Running on P4d platform, Setting NCCL_TOPO_FILE environment variable to /usr/local/share/aws-ofi-nccl/xml/p4d-24xl-topo.xml
# [1,40]<stdout>:algo-6:378:378 [0] NCCL INFO NET/OFI Forcing AWS OFI ndev 4
# [1,40]<stdout>:algo-6:378:378 [0] NCCL INFO NET/OFI Selected Provider is efa
# [1,40]<stdout>:algo-6:378:378 [0] NCCL INFO NET/Plugin: Failed to find ncclCollNetPlugin_v4 symbol.
# [1,40]<stdout>:algo-6:378:378 [0] NCCL INFO Using network AWS Libfabric
# [1,40]<stdout>:NCCL version 2.8.4+cuda11.2
# [1,8]<stdout>:algo-2:378:378 [0] NCCL INFO NET/OFI Forcing AWS OFI ndev 4
# [1,8]<stdout>:algo-2:378:378 [0] NCCL INFO NET/OFI Selected Provider is efa
# [1,8]<stdout>:algo-2:378:378 [0] NCCL INFO NET/Plugin: Failed to find ncclCollNetPlugin_v4 symbol.
# [1,8]<stdout>:algo-2:378:378 [0] NCCL INFO Using network AWS Libfabric
# [1,8]<stdout>:NCCL version 2.8.4+cuda11.2
# [1,56]<stdout>:algo-8:378:378 [0] NCCL INFO NET/OFI Forcing AWS OFI ndev 4
# [1,56]<stdout>:algo-8:378:378 [0] NCCL INFO NET/OFI Selected Provider is efa
# [1,56]<stdout>:algo-8:378:378 [0] NCCL INFO NET/Plugin: Failed to find ncclCollNetPlugin_v4 symbol.
# [1,56]<stdout>:algo-8:378:378 [0] NCCL INFO Using network AWS Libfabric
# [1,56]<stdout>:NCCL version 2.8.4+cuda11.2
# [1,32]<stdout>:algo-5:378:378 [0] NCCL INFO NET/OFI Forcing AWS OFI ndev 4
# [1,32]<stdout>:algo-5:378:378 [0] NCCL INFO NET/OFI Selected Provider is efa
# [1,32]<stdout>:algo-5:378:378 [0] NCCL INFO NET/Plugin: Failed to find ncclCollNetPlugin_v4 symbol.
# [1,32]<stdout>:algo-5:378:378 [0] NCCL INFO Using network AWS Libfabric
# [1,32]<stdout>:NCCL version 2.8.4+cuda11.2
# [1,24]<stdout>:algo-4:378:378 [0] NCCL INFO NET/OFI Forcing AWS OFI ndev 4
# [1,24]<stdout>:algo-4:378:378 [0] NCCL INFO NET/OFI Selected Provider is efa
# [1,24]<stdout>:algo-4:378:378 [0] NCCL INFO NET/Plugin: Failed to find ncclCollNetPlugin_v4 symbol.
# [1,24]<stdout>:algo-4:378:378 [0] NCCL INFO Using network AWS Libfabric
# [1,24]<stdout>:NCCL version 2.8.4+cuda11.2
# [1,48]<stdout>:algo-7:378:378 [0] NCCL INFO NET/OFI Forcing AWS OFI ndev 4
# [1,48]<stdout>:algo-7:378:378 [0] NCCL INFO NET/OFI Selected Provider is efa
# [1,48]<stdout>:algo-7:378:378 [0] NCCL INFO NET/Plugin: Failed to find ncclCollNetPlugin_v4 symbol.
# [1,48]<stdout>:algo-7:378:378 [0] NCCL INFO Using network AWS Libfabric
# [1,48]<stdout>:NCCL version 2.8.4+cuda11.2
# [1,16]<stdout>:algo-3:378:378 [0] NCCL INFO NET/OFI Forcing AWS OFI ndev 4
# [1,16]<stdout>:algo-3:378:378 [0] NCCL INFO NET/OFI Selected Provider is efa
# [1,16]<stdout>:algo-3:378:378 [0] NCCL INFO NET/Plugin: Failed to find ncclCollNetPlugin_v4 symbol.
# [1,16]<stdout>:algo-3:378:378 [0] NCCL INFO Using network AWS Libfabric
# [1,16]<stdout>:NCCL version 2.8.4+cuda11.2
# [1,0]<stdout>:algo-1:453:453 [0] NCCL INFO NET/OFI Forcing AWS OFI ndev 4
# [1,0]<stdout>:algo-1:453:453 [0] NCCL INFO NET/OFI Selected Provider is efa
# [1,0]<stdout>:algo-1:453:453 [0] NCCL INFO NET/Plugin: Failed to find ncclCollNetPlugin_v4 symbol.
# [1,0]<stdout>:algo-1:453:453 [0] NCCL INFO Using network AWS Libfabric
# [1,0]<stdout>:NCCL version 2.8.4+cuda11.2
# [1,41]<stdout>:algo-6:282:282 [1] NCCL INFO Bootstrap : Using eth0:172.30.2.229<0>
# [1,43]<stdout>:algo-6:283:283 [3] NCCL INFO Bootstrap : Using eth0:172.30.2.229<0>
# [1,44]<stdout>:algo-6:285:285 [4] NCCL INFO Bootstrap : Using eth0:172.30.2.229<0>
# [1,45]<stdout>:algo-6:286:286 [5] NCCL INFO Bootstrap : Using eth0:172.30.2.229<0>
# [1,46]<stdout>:algo-6:281:281 [6] NCCL INFO Bootstrap : Using eth0:172.30.2.229<0>
# [1,47]<stdout>:algo-6:284:284 [7] NCCL INFO Bootstrap : Using eth0:172.30.2.229<0>
# [1,42]<stdout>:algo-6:287:287 [2] NCCL INFO Bootstrap : Using eth0:172.30.2.229<0>
# [1,47]<stdout>:algo-6:284:284 [7] NCCL INFO NET/OFI Running on P4d platform, Setting NCCL_TOPO_FILE environment variable to /usr/local/share/aws-ofi-nccl/xml/p4d-24xl-topo.xml
# [1,41]<stdout>:algo-6:282:282 [1] NCCL INFO NET/OFI Running on P4d platform, Setting NCCL_TOPO_FILE environment variable to /usr/local/share/aws-ofi-nccl/xml/p4d-24xl-topo.xml
# [1,43]<stdout>:algo-6:283:283 [3] NCCL INFO NET/OFI Running on P4d platform, Setting NCCL_TOPO_FILE environment variable to /usr/local/share/aws-ofi-nccl/xml/p4d-24xl-topo.xml
# [1,44]<stdout>:algo-6:285:285 [4] NCCL INFO NET/OFI Running on P4d platform, Setting NCCL_TOPO_FILE environment variable to /usr/local/share/aws-ofi-nccl/xml/p4d-24xl-topo.xml
# [1,45]<stdout>:algo-6:286:286 [5] NCCL INFO NET/OFI Running on P4d platform, Setting NCCL_TOPO_FILE environment variable to /usr/local/share/aws-ofi-nccl/xml/p4d-24xl-topo.xml
# [1,46]<stdout>:algo-6:281:281 [6] NCCL INFO NET/OFI Running on P4d platform, Setting NCCL_TOPO_FILE environment variable to /usr/local/share/aws-ofi-nccl/xml/p4d-24xl-topo.xml
# [1,42]<stdout>:algo-6:287:287 [2] NCCL INFO NET/OFI Running on P4d platform, Setting NCCL_TOPO_FILE environment variable to /usr/local/share/aws-ofi-nccl/xml/p4d-24xl-topo.xml
# [1,10]<stdout>:algo-2:287:287 [2] NCCL INFO Bootstrap : Using eth0:172.30.2.8<0>
# [1,12]<stdout>:algo-2:285:285 [4] NCCL INFO Bootstrap : Using eth0:172.30.2.8<0>
# [1,13]<stdout>:algo-2:281:281 [5] NCCL INFO Bootstrap : Using eth0:172.30.2.8<0>
# [1,15]<stdout>:algo-2:282:282 [7] NCCL INFO Bootstrap : Using eth0:172.30.2.8<0>
# [1,14]<stdout>:algo-2:286:286 [6] NCCL INFO Bootstrap : Using eth0:172.30.2.8<0>
# [1,9]<stdout>:algo-2:284:284 [1] NCCL INFO Bootstrap : Using eth0:172.30.2.8<0>
# [1,58]<stdout>:algo-8:284:284 [2] NCCL INFO Bootstrap : Using eth0:172.30.2.181<0>
# [1,61]<stdout>:algo-8:287:287 [5] NCCL INFO Bootstrap : Using eth0:172.30.2.181<0>
# [1,62]<stdout>:algo-8:286:286 [6] NCCL INFO Bootstrap : Using eth0:172.30.2.181<0>
# [1,63]<stdout>:algo-8:285:285 [7] NCCL INFO Bootstrap : Using eth0:172.30.2.181<0>
# [1,11]<stdout>:algo-2:283:283 [3] NCCL INFO Bootstrap : Using eth0:172.30.2.8<0>
# [1,57]<stdout>:algo-8:281:281 [1] NCCL INFO Bootstrap : Using eth0:172.30.2.181<0>
# [1,60]<stdout>:algo-8:283:283 [4] NCCL INFO Bootstrap : Using eth0:172.30.2.181<0>
# [1,10]<stdout>:algo-2:287:287 [2] NCCL INFO NET/OFI Running on P4d platform, Setting NCCL_TOPO_FILE environment variable to /usr/local/share/aws-ofi-nccl/xml/p4d-24xl-topo.xml
# [1,12]<stdout>:algo-2:285:285 [4] NCCL INFO NET/OFI Running on P4d platform, Setting NCCL_TOPO_FILE environment variable to /usr/local/share/aws-ofi-nccl/xml/p4d-24xl-topo.xml
# [1,59]<stdout>:algo-8:282:282 [3] NCCL INFO Bootstrap : Using eth0:172.30.2.181<0>
# [1,15]<stdout>:algo-2:282:282 [7] NCCL INFO NET/OFI Running on P4d platform, Setting NCCL_TOPO_FILE environment variable to /usr/local/share/aws-ofi-nccl/xml/p4d-24xl-topo.xml
# [1,13]<stdout>:algo-2:281:281 [5] NCCL INFO NET/OFI Running on P4d platform, Setting NCCL_TOPO_FILE environment variable to /usr/local/share/aws-ofi-nccl/xml/p4d-24xl-topo.xml
# [1,14]<stdout>:algo-2:286:286 [6] NCCL INFO NET/OFI Running on P4d platform, Setting NCCL_TOPO_FILE environment variable to /usr/local/share/aws-ofi-nccl/xml/p4d-24xl-topo.xml
# [1,9]<stdout>:algo-2:284:284 [1] NCCL INFO NET/OFI Running on P4d platform, Setting NCCL_TOPO_FILE environment variable to /usr/local/share/aws-ofi-nccl/xml/p4d-24xl-topo.xml
# [1,63]<stdout>:algo-8:285:285 [7] NCCL INFO NET/OFI Running on P4d platform, Setting NCCL_TOPO_FILE environment variable to /usr/local/share/aws-ofi-nccl/xml/p4d-24xl-topo.xml
# [1,58]<stdout>:algo-8:284:284 [2] NCCL INFO NET/OFI Running on P4d platform, Setting NCCL_TOPO_FILE environment variable to /usr/local/share/aws-ofi-nccl/xml/p4d-24xl-topo.xml
# [1,61]<stdout>:algo-8:287:287 [5] NCCL INFO NET/OFI Running on P4d platform, Setting NCCL_TOPO_FILE environment variable to /usr/local/share/aws-ofi-nccl/xml/p4d-24xl-topo.xml
# [1,62]<stdout>:algo-8:286:286 [6] NCCL INFO NET/OFI Running on P4d platform, Setting NCCL_TOPO_FILE environment variable to /usr/local/share/aws-ofi-nccl/xml/p4d-24xl-topo.xml
# [1,60]<stdout>:algo-8:283:283 [4] NCCL INFO NET/OFI Running on P4d platform, Setting NCCL_TOPO_FILE environment variable to /usr/local/share/aws-ofi-nccl/xml/p4d-24xl-topo.xml
# [1,11]<stdout>:algo-2:283:283 [3] NCCL INFO NET/OFI Running on P4d platform, Setting NCCL_TOPO_FILE environment variable to /usr/local/share/aws-ofi-nccl/xml/p4d-24xl-topo.xml
# [1,57]<stdout>:algo-8:281:281 [1] NCCL INFO NET/OFI Running on P4d platform, Setting NCCL_TOPO_FILE environment variable to /usr/local/share/aws-ofi-nccl/xml/p4d-24xl-topo.xml
# [1,59]<stdout>:algo-8:282:282 [3] NCCL INFO NET/OFI Running on P4d platform, Setting NCCL_TOPO_FILE environment variable to /usr/local/share/aws-ofi-nccl/xml/p4d-24xl-topo.xml
# ...
# [1,29]<stderr>:WARNING:tensorflow:From resnet_101_imagenet.py:52: shuffle_and_repeat (from tensorflow.python.data.experimental.ops.shuffle_ops) is deprecated and will be removed in a future version.
# [1,29]<stderr>:Instructions for updating:
# [1,29]<stderr>:Use `tf.data.Dataset.shuffle(buffer_size, seed)` followed by `tf.data.Dataset.repeat(count)`. Static tf.data optimizations will take care of using the fused implementation.
# [1,30]<stderr>:WARNING:tensorflow:From resnet_101_imagenet.py:52: shuffle_and_repeat (from tensorflow.python.data.experimental.ops.shuffle_ops) is deprecated and will be removed in a future version.
# [1,30]<stderr>:Instructions for updating:
# [1,30]<stderr>:Use `tf.data.Dataset.shuffle(buffer_size, seed)` followed by `tf.data.Dataset.repeat(count)`. Static tf.data optimizations will take care of using the fused implementation.
# [1,28]<stderr>:WARNING:tensorflow:From resnet_101_imagenet.py:52: shuffle_and_repeat (from tensorflow.python.data.experimental.ops.shuffle_ops) is deprecated and will be removed in a future version.
# [1,28]<stderr>:Instructions for updating:
# [1,28]<stderr>:Use `tf.data.Dataset.shuffle(buffer_size, seed)` followed by `tf.data.Dataset.repeat(count)`. Static tf.data optimizations will take care of using the fused implementation.
# [1,55]<stderr>:WARNING:tensorflow:From resnet_101_imagenet.py:52: shuffle_and_repeat (from tensorflow.python.data.experimental.ops.shuffle_ops) is deprecated and will be removed in a future version.
# [1,55]<stderr>:Instructions for updating:
# [1,55]<stderr>:Use `tf.data.Dataset.shuffle(buffer_size, seed)` followed by `tf.data.Dataset.repeat(count)`. Static tf.data optimizations will take care of using the fused implementation.
# [1,54]<stderr>:WARNING:tensorflow:From resnet_101_imagenet.py:52: shuffle_and_repeat (from tensorflow.python.data.experimental.ops.shuffle_ops) is deprecated and will be removed in a future version.
# [1,54]<stderr>:Instructions for updating:
# [1,54]<stderr>:Use `tf.data.Dataset.shuffle(buffer_size, seed)` followed by `tf.data.Dataset.repeat(count)`. Static tf.data optimizations will take care of using the fused implementation.
# [1,49]<stderr>:WARNING:tensorflow:From resnet_101_imagenet.py:52: shuffle_and_repeat (from tensorflow.python.data.experimental.ops.shuffle_ops) is deprecated and will be removed in a future version.
# [1,49]<stderr>:Instructions for updating:
# [1,49]<stderr>:Use `tf.data.Dataset.shuffle(buffer_size, seed)` followed by `tf.data.Dataset.repeat(count)`. Static tf.data optimizations will take care of using the fused implementation.
# [1,50]<stderr>:WARNING:tensorflow:From resnet_101_imagenet.py:52: shuffle_and_repeat (from tensorflow.python.data.experimental.ops.shuffle_ops) is deprecated and will be removed in a future version.
# [1,50]<stderr>:Instructions for updating:
# [1,50]<stderr>:Use `tf.data.Dataset.shuffle(buffer_size, seed)` followed by `tf.data.Dataset.repeat(count)`. Static tf.data optimizations will take care of using the fused implementation.
# [1,51]<stderr>:WARNING:tensorflow:From resnet_101_imagenet.py:52: shuffle_and_repeat (from tensorflow.python.data.experimental.ops.shuffle_ops) is deprecated and will be removed in a future version.
# [1,51]<stderr>:Instructions for updating:
# [1,51]<stderr>:Use `tf.data.Dataset.shuffle(buffer_size, seed)` followed by `tf.data.Dataset.repeat(count)`. Static tf.data optimizations will take care of using the fused implementation.
# [1,48]<stderr>:WARNING:tensorflow:From resnet_101_imagenet.py:52: shuffle_and_repeat (from tensorflow.python.data.experimental.ops.shuffle_ops) is deprecated and will be removed in a future version.
# [1,48]<stderr>:Instructions for updating:
# [1,48]<stderr>:Use `tf.data.Dataset.shuffle(buffer_size, seed)` followed by `tf.data.Dataset.repeat(count)`. Static tf.data optimizations will take care of using the fused implementation.
# [1,52]<stderr>:WARNING:tensorflow:From resnet_101_imagenet.py:52: shuffle_and_repeat (from tensorflow.python.data.experimental.ops.shuffle_ops) is deprecated and will be removed in a future version.
# [1,52]<stderr>:Instructions for updating:
# [1,52]<stderr>:Use `tf.data.Dataset.shuffle(buffer_size, seed)` followed by `tf.data.Dataset.repeat(count)`. Static tf.data optimizations will take care of using the fused implementation.
# [1,53]<stderr>:WARNING:tensorflow:From resnet_101_imagenet.py:52: shuffle_and_repeat (from tensorflow.python.data.experimental.ops.shuffle_ops) is deprecated and will be removed in a future version.
# [1,53]<stderr>:Instructions for updating:
# [1,53]<stderr>:Use `tf.data.Dataset.shuffle(buffer_size, seed)` followed by `tf.data.Dataset.repeat(count)`. Static tf.data optimizations will take care of using the fused implementation.
# [1,1]<stderr>:WARNING:tensorflow:From resnet_101_imagenet.py:52: shuffle_and_repeat (from tensorflow.python.data.experimental.ops.shuffle_ops) is deprecated and will be removed in a future version.
# [1,1]<stderr>:Instructions for updating:
# [1,1]<stderr>:Use `tf.data.Dataset.shuffle(buffer_size, seed)` followed by `tf.data.Dataset.repeat(count)`. Static tf.data optimizations will take care of using the fused implementation.
# [1,5]<stderr>:WARNING:tensorflow:From resnet_101_imagenet.py:52: shuffle_and_repeat (from tensorflow.python.data.experimental.ops.shuffle_ops) is deprecated and will be removed in a future version.
# [1,5]<stderr>:Instructions for updating:
# [1,5]<stderr>:Use `tf.data.Dataset.shuffle(buffer_size, seed)` followed by `tf.data.Dataset.repeat(count)`. Static tf.data optimizations will take care of using the fused implementation.
# [1,7]<stderr>:WARNING:tensorflow:From resnet_101_imagenet.py:52: shuffle_and_repeat (from tensorflow.python.data.experimental.ops.shuffle_ops) is deprecated and will be removed in a future version.
# [1,7]<stderr>:Instructions for updating:
# [1,7]<stderr>:Use `tf.data.Dataset.shuffle(buffer_size, seed)` followed by `tf.data.Dataset.repeat(count)`. Static tf.data optimizations will take care of using the fused implementation.
# [1,3]<stderr>:WARNING:tensorflow:From resnet_101_imagenet.py:52: shuffle_and_repeat (from tensorflow.python.data.experimental.ops.shuffle_ops) is deprecated and will be removed in a future version.
# [1,3]<stderr>:Instructions for updating:
# [1,3]<stderr>:Use `tf.data.Dataset.shuffle(buffer_size, seed)` followed by `tf.data.Dataset.repeat(count)`. Static tf.data optimizations will take care of using the fused implementation.
# [1,6]<stderr>:WARNING:tensorflow:From resnet_101_imagenet.py:52: shuffle_and_repeat (from tensorflow.python.data.experimental.ops.shuffle_ops) is deprecated and will be removed in a future version.
# [1,6]<stderr>:Instructions for updating:
# [1,6]<stderr>:Use `tf.data.Dataset.shuffle(buffer_size, seed)` followed by `tf.data.Dataset.repeat(count)`. Static tf.data optimizations will take care of using the fused implementation.
# [1,4]<stderr>:WARNING:tensorflow:From resnet_101_imagenet.py:52: shuffle_and_repeat (from tensorflow.python.data.experimental.ops.shuffle_ops) is deprecated and will be removed in a future version.
# [1,4]<stderr>:Instructions for updating:
# [1,4]<stderr>:Use `tf.data.Dataset.shuffle(buffer_size, seed)` followed by `tf.data.Dataset.repeat(count)`. Static tf.data optimizations will take care of using the fused implementation.
# [1,2]<stderr>:WARNING:tensorflow:From resnet_101_imagenet.py:52: shuffle_and_repeat (from tensorflow.python.data.experimental.ops.shuffle_ops) is deprecated and will be removed in a future version.
# [1,2]<stderr>:Instructions for updating:
# [1,2]<stderr>:Use `tf.data.Dataset.shuffle(buffer_size, seed)` followed by `tf.data.Dataset.repeat(count)`. Static tf.data optimizations will take care of using the fused implementation.
# [1,0]<stderr>:WARNING:tensorflow:From resnet_101_imagenet.py:52: shuffle_and_repeat (from tensorflow.python.data.experimental.ops.shuffle_ops) is deprecated and will be removed in a future version.
# [1,0]<stderr>:Instructions for updating:
# [1,0]<stderr>:Use `tf.data.Dataset.shuffle(buffer_size, seed)` followed by `tf.data.Dataset.repeat(count)`. Static tf.data optimizations will take care of using the fused implementation.
# [1,17]<stderr>:WARNING:tensorflow:From resnet_101_imagenet.py:52: shuffle_and_repeat (from tensorflow.python.data.experimental.ops.shuffle_ops) is deprecated and will be removed in a future version.
# [1,17]<stderr>:Instructions for updating:
# [1,17]<stderr>:Use `tf.data.Dataset.shuffle(buffer_size, seed)` followed by `tf.data.Dataset.repeat(count)`. Static tf.data optimizations will take care of using the fused implementation.
# [1,18]<stderr>:WARNING:tensorflow:From resnet_101_imagenet.py:52: shuffle_and_repeat (from tensorflow.python.data.experimental.ops.shuffle_ops) is deprecated and will be removed in a future version.
# [1,18]<stderr>:Instructions for updating:
# [1,18]<stderr>:Use `tf.data.Dataset.shuffle(buffer_size, seed)` followed by `tf.data.Dataset.repeat(count)`. Static tf.data optimizations will take care of using the fused implementation.
# [1,21]<stderr>:WARNING:tensorflow:From resnet_101_imagenet.py:52: shuffle_and_repeat (from tensorflow.python.data.experimental.ops.shuffle_ops) is deprecated and will be removed in a future version.
# [1,21]<stderr>:Instructions for updating:
# [1,21]<stderr>:Use `tf.data.Dataset.shuffle(buffer_size, seed)` followed by `tf.data.Dataset.repeat(count)`. Static tf.data optimizations will take care of using the fused implementation.
# [1,16]<stderr>:WARNING:tensorflow:From resnet_101_imagenet.py:52: shuffle_and_repeat (from tensorflow.python.data.experimental.ops.shuffle_ops) is deprecated and will be removed in a future version.
# [1,16]<stderr>:Instructions for updating:
# [1,16]<stderr>:Use `tf.data.Dataset.shuffle(buffer_size, seed)` followed by `tf.data.Dataset.repeat(count)`. Static tf.data optimizations will take care of using the fused implementation.
# [1,19]<stderr>:WARNING:tensorflow:From resnet_101_imagenet.py:52: shuffle_and_repeat (from tensorflow.python.data.experimental.ops.shuffle_ops) is deprecated and will be removed in a future version.
# [1,19]<stderr>:Instructions for updating:
# [1,19]<stderr>:Use `tf.data.Dataset.shuffle(buffer_size, seed)` followed by `tf.data.Dataset.repeat(count)`. Static tf.data optimizations will take care of using the fused implementation.
# [1,22]<stderr>:WARNING:tensorflow:From resnet_101_imagenet.py:52: shuffle_and_repeat (from tensorflow.python.data.experimental.ops.shuffle_ops) is deprecated and will be removed in a future version.
# [1,22]<stderr>:Instructions for updating:
# [1,22]<stderr>:Use `tf.data.Dataset.shuffle(buffer_size, seed)` followed by `tf.data.Dataset.repeat(count)`. Static tf.data optimizations will take care of using the fused implementation.
# [1,20]<stderr>:WARNING:tensorflow:From resnet_101_imagenet.py:52: shuffle_and_repeat (from tensorflow.python.data.experimental.ops.shuffle_ops) is deprecated and will be removed in a future version.
# [1,20]<stderr>:Instructions for updating:
# [1,20]<stderr>:Use `tf.data.Dataset.shuffle(buffer_size, seed)` followed by `tf.data.Dataset.repeat(count)`. Static tf.data optimizations will take care of using the fused implementation.
# [1,23]<stderr>:WARNING:tensorflow:From resnet_101_imagenet.py:52: shuffle_and_repeat (from tensorflow.python.data.experimental.ops.shuffle_ops) is deprecated and will be removed in a future version.
# [1,23]<stderr>:Instructions for updating:
# [1,23]<stderr>:Use `tf.data.Dataset.shuffle(buffer_size, seed)` followed by `tf.data.Dataset.repeat(count)`. Static tf.data optimizations will take care of using the fused implementation.
#
# 2021-10-19 21:01:16,901 sagemaker-training-toolkit INFO     Orted process exited
# 2021-10-19 21:01:16,866 sagemaker-training-toolkit INFO     Orted process exited
# 2021-10-19 21:01:16,905 sagemaker-training-toolkit INFO     Orted process exited
# 2021-10-19 21:01:16,881 sagemaker-training-toolkit INFO     Orted process exited
# 2021-10-19 21:01:16,900 sagemaker-training-toolkit INFO     Orted process exited
# 2021-10-19 21:01:16,902 sagemaker-training-toolkit INFO     Orted process exited
# 2021-10-19 21:01:16,889 sagemaker-training-toolkit INFO     Orted process exited
# 2021-10-19 21:01:46,905 sagemaker-training-toolkit INFO     MPI process finished.
# 2021-10-19 21:01:46,906 sagemaker_tensorflow_container.training WARNING  No model artifact is saved under path /opt/ml/model. Your training job will not save any model files to S3.
# For details of how to construct your training script see:
# https://sagemaker.readthedocs.io/en/stable/using_tf.html#adapting-your-local-tensorflow-script
# 2021-10-19 21:01:46,906 sagemaker-training-toolkit INFO     Reporting training SUCCESS
# 2021-10-19 21:01:46,895 sagemaker-training-toolkit INFO     MPI process finished.
# 2021-10-19 21:01:46,896 sagemaker_tensorflow_container.training WARNING  No model artifact is saved under path /opt/ml/model. Your training job will not save any model files to S3.
# For details of how to construct your training script see:
# https://sagemaker.readthedocs.io/en/stable/using_tf.html#adapting-your-local-tensorflow-script
# 2021-10-19 21:01:46,896 sagemaker-training-toolkit INFO     Reporting training SUCCESS
# 2021-10-19 21:01:46,935 sagemaker-training-toolkit INFO     MPI process finished.
# 2021-10-19 21:01:46,935 sagemaker_tensorflow_container.training WARNING  No model artifact is saved under path /opt/ml/model. Your training job will not save any model files to S3.
# For details of how to construct your training script see:
# https://sagemaker.readthedocs.io/en/stable/using_tf.html#adapting-your-local-tensorflow-script
# 2021-10-19 21:01:46,935 sagemaker-training-toolkit INFO     Reporting training SUCCESS
# 2021-10-19 21:01:46,912 sagemaker-training-toolkit INFO     MPI process finished.
# 2021-10-19 21:01:46,912 sagemaker_tensorflow_container.training WARNING  No model artifact is saved under path /opt/ml/model. Your training job will not save any model files to S3.
# For details of how to construct your training script see:
# https://sagemaker.readthedocs.io/en/stable/using_tf.html#adapting-your-local-tensorflow-script
# 2021-10-19 21:01:46,912 sagemaker-training-toolkit INFO     Reporting training SUCCESS
# 2021-10-19 21:01:46,930 sagemaker-training-toolkit INFO     MPI process finished.
# 2021-10-19 21:01:46,931 sagemaker_tensorflow_container.training WARNING  No model artifact is saved under path /opt/ml/model. Your training job will not save any model files to S3.
# For details of how to construct your training script see:
# https://sagemaker.readthedocs.io/en/stable/using_tf.html#adapting-your-local-tensorflow-script
# 2021-10-19 21:01:46,931 sagemaker-training-toolkit INFO     Reporting training SUCCESS
# 2021-10-19 21:01:46,932 sagemaker-training-toolkit INFO     MPI process finished.
# 2021-10-19 21:01:46,933 sagemaker_tensorflow_container.training WARNING  No model artifact is saved under path /opt/ml/model. Your training job will not save any model files to S3.
# For details of how to construct your training script see:
# https://sagemaker.readthedocs.io/en/stable/using_tf.html#adapting-your-local-tensorflow-script
# 2021-10-19 21:01:46,933 sagemaker-training-toolkit INFO     Reporting training SUCCESS
# 2021-10-19 21:01:46,919 sagemaker-training-toolkit INFO     MPI process finished.
# 2021-10-19 21:01:46,920 sagemaker_tensorflow_container.training WARNING  No model artifact is saved under path /opt/ml/model. Your training job will not save any model files to S3.
# For details of how to construct your training script see:
# https://sagemaker.readthedocs.io/en/stable/using_tf.html#adapting-your-local-tensorflow-script
# 2021-10-19 21:01:46,920 sagemaker-training-toolkit INFO     Reporting training SUCCESS
#
# 2021-10-19 21:01:55 Uploading - Uploading generated training model
# 2021-10-19 21:01:55 Completed - Training job completed
# Training seconds: 6168
# Billable seconds: 6168
